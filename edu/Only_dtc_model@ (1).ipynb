# %%
import pandas as pd
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
def norma(x):
    if(x <= 10):
        return x
    elif(x == 12 or x == 13):
        return 10
    return 5

# %%
scaler = StandardScaler()
df = pd.read_csv("meteo_TRAIN.csv")
df["total cloud cover"] = df["total cloud cover"].apply(norma)
weather = list(df["precipitation true"].iloc[1:])
df.drop(len(df)-1, axis=0, inplace=True)
df["precipitation true"] = weather
dataset = df.drop(["precipitation false", "Unnamed: 0", "weather between time", "night"], axis=1)
result_dataset = dataset.drop(["total cloud cover"], axis=1)
X = np.array(dataset.drop("precipitation true", axis=1))
X = scaler.fit_transform(X)
y = np.array(dataset["precipitation true"])

X_res = np.array(result_dataset.drop("precipitation true", axis=1))
X_res = scaler.fit_transform(X)
y_res = np.array(result_dataset["precipitation true"])

# %%
history = []
for depth in range(2, 6):
    print(depth)
    for criterion in ("gini", "entropy", "log_loss"):
        for n_estimators in range(50, 500, 50):
            for split in range(2, 5):
                reg = DecisionTreeClassifier(max_depth = depth, criterion = criterion, min_samples_split = split)
                cvs = cross_val_score(reg, X, y, cv=5, scoring="accuracy")
                mean_cvs = np.mean(cvs)
                history.append((np.abs(mean_cvs), depth, criterion, n_estimators,split))
# Out:
# 2
# 3
# 4

# %%
sorted(history)[::-1]
# Out:
# [(0.9136276894583496, 5, 'log_loss', 450, 4),
#  (0.9136276894583496, 5, 'log_loss', 300, 4),
#  (0.9136276894583496, 5, 'log_loss', 200, 3),
#  (0.9136276894583496, 5, 'log_loss', 200, 2),
#  (0.9136276894583496, 5, 'log_loss', 150, 4),
#  (0.9136276894583496, 5, 'log_loss', 100, 3),
#  (0.9136276894583496, 5, 'log_loss', 50, 4),
#  (0.9136276894583496, 5, 'log_loss', 50, 3),
#  (0.9136276894583496, 5, 'entropy', 450, 4),
#  (0.9136276894583496, 5, 'entropy', 450, 2),
#  (0.9136276894583496, 5, 'entropy', 350, 4),
#  (0.9136276894583496, 5, 'entropy', 200, 2),
#  (0.9136276894583496, 5, 'entropy', 150, 4),
#  (0.9136276894583496, 5, 'entropy', 100, 4),
#  (0.9136276894583496, 5, 'entropy', 50, 4),
#  (0.9136152136302662, 5, 'log_loss', 400, 3),
#  (0.9136152136302662, 5, 'log_loss', 400, 2),
#  (0.9136152136302662, 5, 'log_loss', 300, 2),
#  (0.9136152136302662, 5, 'log_loss', 250, 3),
#  (0.9136152136302662, 5, 'log_loss', 250, 2),
#  (0.9136152136302662, 5, 'log_loss', 50, 2),
#  (0.9136152136302662, 5, 'entropy', 300, 2),
#  (0.9136152136302662, 5, 'entropy', 250, 2),
#  (0.9136152136302662, 5, 'entropy', 200, 4),
#  (0.9136152136302662, 5, 'entropy', 200, 3),
#  (0.9136152136302662, 5, 'entropy', 150, 3),
#  (0.9136152136302662, 5, 'entropy', 150, 2),
#  (0.9136152136302662, 5, 'entropy', 100, 3),
#  (0.9136152136302662, 5, 'entropy', 100, 2),
#  (0.9136027346890634, 5, 'gini', 450, 3),
#  (0.9136027346890634, 5, 'gini', 450, 2),
#  (0.9136027346890634, 5, 'gini', 400, 4),
#  (0.9136027346890634, 5, 'gini', 350, 4),
#  (0.9136027346890634, 5, 'gini', 350, 3),
#  (0.9136027346890634, 5, 'gini', 300, 4),
#  (0.9136027346890634, 5, 'gini', 250, 3),
#  (0.9136027346890634, 5, 'gini', 250, 2),
#  (0.9136027346890634, 5, 'gini', 200, 4),
#  (0.9136027346890634, 5, 'gini', 200, 3),
#  (0.9136027346890634, 5, 'gini', 200, 2),
#  (0.9136027346890634, 5, 'gini', 150, 4),
#  (0.9136027346890634, 5, 'gini', 150, 3),
#  (0.9136027346890634, 5, 'gini', 100, 2),
#  (0.9136027346890634, 5, 'gini', 50, 2),
#  (0.9135902619741003, 5, 'log_loss', 350, 3),
#  (0.9135902619741003, 5, 'log_loss', 250, 4),
#  (0.9135902619741003, 5, 'log_loss', 150, 2),
#  (0.9135902619741003, 5, 'log_loss', 100, 4),
#  (0.9135902619741003, 5, 'entropy', 400, 3),
#  (0.913577786146017, 5, 'log_loss', 450, 3),
#  (0.913577786146017, 5, 'log_loss', 450, 2),
#  (0.913577786146017, 5, 'log_loss', 400, 4),
#  (0.913577786146017, 5, 'log_loss', 350, 4),
#  (0.913577786146017, 5, 'log_loss', 350, 2),
#  (0.913577786146017, 5, 'log_loss', 300, 3),
#  (0.913577786146017, 5, 'log_loss', 200, 4),
#  (0.913577786146017, 5, 'log_loss', 150, 3),
#  (0.913577786146017, 5, 'log_loss', 100, 2),
#  (0.913577786146017, 5, 'entropy', 450, 3),
#  (0.913577786146017, 5, 'entropy', 400, 4),
#  (0.913577786146017, 5, 'entropy', 400, 2),
#  (0.913577786146017, 5, 'entropy', 350, 3),
#  (0.913577786146017, 5, 'entropy', 350, 2),
#  (0.913577786146017, 5, 'entropy', 300, 4),
#  (0.913577786146017, 5, 'entropy', 300, 3),
#  (0.913577786146017, 5, 'entropy', 250, 4),
#  (0.913577786146017, 5, 'entropy', 250, 3),
#  (0.913577786146017, 5, 'entropy', 50, 3),
#  (0.913577786146017, 5, 'entropy', 50, 2),
#  (0.913577783032897, 5, 'gini', 450, 4),
#  (0.913577783032897, 5, 'gini', 400, 3),
#  (0.913577783032897, 5, 'gini', 400, 2),
#  (0.913577783032897, 5, 'gini', 350, 2),
#  (0.913577783032897, 5, 'gini', 300, 3),
#  (0.913577783032897, 5, 'gini', 300, 2),
#  (0.913577783032897, 5, 'gini', 250, 4),
#  (0.913577783032897, 5, 'gini', 150, 2),
#  (0.913577783032897, 5, 'gini', 100, 4),
#  (0.913577783032897, 5, 'gini', 100, 3),
#  (0.913577783032897, 5, 'gini', 50, 4),
#  (0.913577783032897, 5, 'gini', 50, 3),
#  (0.9134779764082325, 6, 'entropy', 250, 3),
#  (0.9134655005801493, 6, 'log_loss', 450, 2),
#  (0.9134655005801493, 6, 'log_loss', 350, 3),
#  (0.9134655005801493, 6, 'log_loss', 50, 2),
#  (0.9134655005801493, 6, 'entropy', 350, 2),
#  (0.9134530247520664, 6, 'log_loss', 400, 3),
#  (0.9134530247520664, 6, 'log_loss', 300, 4),
#  (0.9134530247520664, 6, 'log_loss', 250, 3),
#  (0.9134405489239832, 6, 'log_loss', 450, 4),
#  (0.9134405489239832, 6, 'log_loss', 200, 4),
#  (0.9134405489239832, 6, 'log_loss', 150, 4),
#  (0.9134405489239832, 6, 'log_loss', 150, 3),
#  (0.9134405489239832, 6, 'log_loss', 150, 2),
#  (0.9134405489239832, 6, 'log_loss', 50, 4),
#  (0.9134405489239832, 6, 'log_loss', 50, 3),
#  (0.9134405489239832, 6, 'entropy', 400, 3),
#  (0.9134405458108633, 6, 'gini', 450, 4),
#  (0.9134280730959, 6, 'log_loss', 300, 2),
#  (0.9134280730959, 6, 'log_loss', 250, 2),
#  (0.9134280730959, 6, 'log_loss', 100, 4),
#  (0.9134280730959, 6, 'entropy', 450, 4),
#  (0.9134280730959, 6, 'entropy', 450, 3),
#  (0.9134280730959, 6, 'entropy', 350, 4),
#  (0.9134280730959, 6, 'entropy', 300, 3),
#  (0.9134280730959, 6, 'entropy', 300, 2),
#  (0.9134280730959, 6, 'entropy', 200, 3),
#  (0.9134280730959, 6, 'entropy', 150, 2),
#  (0.9134280730959, 6, 'entropy', 100, 4),
#  (0.9134280730959, 6, 'entropy', 100, 3),
#  (0.9134280730959, 6, 'entropy', 50, 3),
#  (0.9134280730959, 6, 'entropy', 50, 2),
#  (0.9134280699827804, 6, 'gini', 400, 3),
#  (0.9134280699827804, 6, 'gini', 350, 3),
#  (0.9134280699827804, 6, 'gini', 100, 3),
#  (0.9134280699827804, 6, 'gini', 100, 2),
#  (0.9134280699827804, 6, 'gini', 50, 2),
#  (0.9134155972678171, 6, 'log_loss', 100, 3),
#  (0.9134155972678171, 6, 'entropy', 450, 2),
#  (0.9134155972678171, 6, 'entropy', 350, 3),
#  (0.9134155972678171, 6, 'entropy', 150, 3),
#  (0.9134155972678171, 6, 'entropy', 100, 2),
#  (0.9134155941546972, 6, 'gini', 450, 3),
#  (0.9134155941546972, 6, 'gini', 450, 2),
#  (0.9134155941546972, 6, 'gini', 400, 2),
#  (0.9134155941546972, 6, 'gini', 350, 2),
#  (0.9134155941546972, 6, 'gini', 250, 2),
#  (0.9134155941546972, 6, 'gini', 200, 3),
#  (0.9134155941546972, 6, 'gini', 150, 3),
#  (0.9134155941546972, 6, 'gini', 150, 2),
#  (0.9134155941546972, 6, 'gini', 50, 4),
#  (0.9134155925981371, 6, 'gini', 400, 4),
#  (0.9134155925981371, 6, 'gini', 300, 4),
#  (0.9134155925981371, 6, 'gini', 200, 4),
#  (0.9134155925981371, 6, 'gini', 100, 4),
#  (0.9134031214397339, 6, 'log_loss', 450, 3),
#  (0.9134031214397339, 6, 'log_loss', 350, 4),
#  (0.9134031214397339, 6, 'log_loss', 350, 2),
#  (0.9134031214397339, 6, 'log_loss', 250, 4),
#  (0.9134031214397339, 6, 'log_loss', 200, 3),
#  (0.9134031214397339, 6, 'log_loss', 100, 2),
#  (0.9134031214397339, 6, 'entropy', 400, 2),
#  (0.9134031214397339, 6, 'entropy', 250, 2),
#  (0.9134031214397339, 6, 'entropy', 200, 2),
#  (0.9134031214397339, 6, 'entropy', 150, 4),
#  (0.913403118326614, 7, 'log_loss', 150, 3),
#  (0.9134031167700541, 6, 'gini', 300, 2),
#  (0.9134031167700541, 6, 'gini', 250, 3),
#  (0.9134031167700541, 6, 'gini', 50, 3),
#  (0.9133906456116507, 6, 'log_loss', 300, 3),
#  (0.9133906456116507, 6, 'entropy', 400, 4),
#  (0.9133906456116507, 6, 'entropy', 200, 4),
#  (0.9133906424985309, 7, 'entropy', 350, 3),
#  (0.913390640941971, 6, 'gini', 350, 4),
#  (0.913390640941971, 6, 'gini', 300, 3),
#  (0.913390640941971, 6, 'gini', 250, 4),
#  (0.913390640941971, 6, 'gini', 200, 2),
#  (0.913390640941971, 6, 'gini', 150, 4),
#  (0.9133781697835678, 6, 'log_loss', 400, 4),
#  (0.9133781697835678, 6, 'log_loss', 400, 2),
#  (0.9133781697835678, 6, 'log_loss', 200, 2),
#  (0.9133781697835678, 6, 'entropy', 300, 4),
#  (0.9133781697835678, 6, 'entropy', 250, 4),
#  (0.9133781697835678, 6, 'entropy', 50, 4),
#  (0.9133781666704477, 7, 'log_loss', 350, 2),
#  (0.9133781666704477, 7, 'log_loss', 300, 2),
#  (0.9133781666704477, 7, 'log_loss', 250, 2),
#  (0.9133781666704477, 7, 'entropy', 100, 4),
#  (0.9133781666704477, 7, 'entropy', 100, 2),
#  (0.9133656908423647, 7, 'log_loss', 350, 3),
#  (0.9133656908423647, 7, 'log_loss', 250, 3),
#  (0.9133656908423647, 7, 'entropy', 250, 3),
#  (0.9133656908423647, 7, 'entropy', 200, 3),
#  (0.9133656908423647, 7, 'entropy', 150, 3),
#  (0.9133656900640847, 7, 'entropy', 300, 4),
#  (0.9133532150142816, 7, 'log_loss', 450, 3),
#  (0.9133532150142816, 7, 'entropy', 450, 3),
#  (0.9133532150142816, 7, 'entropy', 400, 4),
#  (0.9133532150142816, 7, 'entropy', 100, 3),
#  (0.9133532142360016, 7, 'entropy', 250, 4),
#  (0.9133532142360016, 7, 'entropy', 150, 2),
#  (0.9133532134577218, 7, 'gini', 50, 3),
#  (0.9133407391861985, 7, 'log_loss', 300, 4),
#  (0.9133407391861985, 7, 'log_loss', 100, 4),
#  (0.9133407391861985, 7, 'log_loss', 100, 2),
#  (0.9133407391861985, 7, 'entropy', 350, 4),
#  (0.9133407391861985, 7, 'entropy', 300, 3),
#  (0.9133407384079186, 7, 'log_loss', 400, 2),
#  (0.9133407384079186, 7, 'log_loss', 300, 3),
#  (0.9133407384079186, 7, 'log_loss', 150, 2),
#  (0.9133407384079186, 7, 'log_loss', 100, 3),
#  (0.9133407384079184, 7, 'log_loss', 250, 4),
#  (0.9133407384079184, 7, 'entropy', 450, 2),
#  (0.9133407384079184, 7, 'entropy', 50, 3),
#  (0.9133407368513586, 7, 'gini', 200, 4),
#  (0.9133407368513586, 7, 'gini', 100, 3),
#  (0.9133282633581155, 7, 'log_loss', 400, 3),
#  (0.9133282633581155, 7, 'log_loss', 200, 3),
#  (0.9133282633581155, 7, 'log_loss', 50, 2),
#  (0.9133282633581155, 7, 'entropy', 300, 2),
#  (0.9133282633581155, 7, 'entropy', 200, 4),
#  (0.9133282633581155, 7, 'entropy', 50, 4),
#  (0.9133282625798355, 7, 'log_loss', 450, 2),
#  (0.9133282625798355, 7, 'log_loss', 200, 4),
#  (0.9133282625798355, 7, 'log_loss', 50, 4),
#  (0.9133282625798355, 7, 'log_loss', 50, 3),
#  (0.9133282625798355, 7, 'entropy', 450, 4),
#  (0.9133282625798355, 7, 'entropy', 50, 2),
#  (0.9133282602449955, 7, 'gini', 50, 2),
#  (0.9133157875300324, 7, 'log_loss', 400, 4),
#  (0.9133157875300324, 7, 'log_loss', 350, 4),
#  (0.9133157875300324, 7, 'log_loss', 150, 4),
#  (0.9133157875300324, 7, 'entropy', 400, 3),
#  (0.9133157875300324, 7, 'entropy', 350, 2),
#  (0.9133157875300324, 7, 'entropy', 200, 2),
#  (0.9133157867517523, 7, 'log_loss', 450, 4),
#  (0.9133157851951925, 7, 'gini', 50, 4),
#  (0.9133157844169123, 7, 'gini', 200, 2),
#  (0.9133157836386324, 8, 'entropy', 100, 3),
#  (0.9133157836386324, 7, 'gini', 400, 4),
#  (0.9133157836386324, 7, 'gini', 400, 3),
#  (0.9133157836386324, 7, 'gini', 400, 2),
#  (0.9133157836386324, 7, 'gini', 350, 4),
#  (0.9133157836386324, 7, 'gini', 100, 4),
#  (0.9133033117019492, 7, 'log_loss', 200, 2),
#  (0.9133033117019492, 7, 'entropy', 400, 2),
#  (0.9133033117019492, 7, 'entropy', 250, 2),
#  (0.9133033101453893, 7, 'gini', 250, 3),
#  (0.9133033093671094, 7, 'gini', 250, 4),
#  (0.9132908350955862, 7, 'entropy', 150, 4),
#  (0.9132908327607463, 7, 'gini', 150, 4),
#  (0.9132908327607462, 7, 'gini', 300, 2),
#  (0.9132908304259063, 7, 'gini', 450, 2),
#  (0.9132783569326632, 7, 'gini', 350, 3),
#  (0.9132783569326632, 7, 'gini', 100, 2),
#  (0.9132783561543831, 7, 'gini', 300, 4),
#  (0.9132783561543831, 7, 'gini', 200, 3),
#  (0.9132658803263002, 7, 'gini', 450, 3),
#  (0.9132658803263001, 7, 'gini', 350, 2),
#  (0.9132658803263001, 7, 'gini', 300, 3),
#  (0.9132534052764969, 8, 'log_loss', 100, 3),
#  (0.913253404498217, 7, 'gini', 450, 4),
#  (0.913253404498217, 7, 'gini', 150, 3),
#  (0.913253403719937, 8, 'entropy', 450, 2),
#  (0.913253402941657, 7, 'gini', 250, 2),
#  (0.913240929448414, 8, 'log_loss', 250, 3),
#  (0.9132409294484137, 8, 'log_loss', 400, 4),
#  (0.9132409294484137, 8, 'log_loss', 50, 3),
#  (0.913240928670134, 8, 'entropy', 450, 3),
#  (0.913240928670134, 8, 'entropy', 350, 2),
#  (0.913240928670134, 8, 'entropy', 200, 2),
#  (0.913240928670134, 8, 'entropy', 150, 2),
#  (0.9132409278918538, 8, 'entropy', 200, 3),
#  (0.9132284536203308, 8, 'entropy', 450, 4),
#  (0.9132284528420509, 8, 'log_loss', 300, 3),
#  (0.9132284528420509, 8, 'entropy', 250, 4),
#  (0.9132284528420508, 8, 'log_loss', 400, 2),
#  (0.9132284528420508, 8, 'log_loss', 150, 4),
#  (0.9132284528420508, 8, 'log_loss', 150, 3),
#  (0.9132284528420508, 8, 'entropy', 400, 3),
#  (0.9132284528420508, 8, 'entropy', 400, 2),
#  (0.9132284520637709, 8, 'log_loss', 450, 3),
#  (0.9132159770139678, 8, 'log_loss', 400, 3),
#  (0.9132159770139678, 8, 'log_loss', 250, 4),
#  (0.9132159770139678, 8, 'entropy', 300, 2),
#  (0.9132159770139676, 8, 'log_loss', 350, 3),
#  (0.9132159770139676, 8, 'entropy', 400, 4),
#  (0.9132159770139676, 8, 'entropy', 300, 3),
#  (0.9132159770139676, 8, 'entropy', 250, 2),
#  (0.9132159746791277, 7, 'gini', 150, 2),
#  (0.9132035019641647, 8, 'log_loss', 450, 2),
#  (0.9132035019641647, 8, 'log_loss', 200, 3),
#  (0.9132035019641644, 8, 'log_loss', 300, 4),
#  (0.9132035019641644, 8, 'log_loss', 150, 2),
#  (0.9132035011858847, 8, 'log_loss', 300, 2),
#  (0.9132035011858847, 8, 'entropy', 250, 3),
#  (0.9132035011858847, 8, 'entropy', 50, 4),
#  (0.9131910261360815, 8, 'log_loss', 350, 2),
#  (0.9131910261360815, 8, 'log_loss', 250, 2),
#  (0.9131910261360815, 8, 'entropy', 350, 4),
#  (0.9131910253578017, 8, 'log_loss', 50, 4),
#  (0.9131910253578015, 8, 'entropy', 150, 4),
#  (0.9131910253578015, 8, 'entropy', 100, 2),
#  (0.9131910245795216, 8, 'log_loss', 200, 4),
#  (0.9131910245795216, 8, 'log_loss', 200, 2),
#  (0.9131910222446816, 8, 'gini', 350, 2),
#  (0.9131785503079983, 8, 'entropy', 200, 4),
#  (0.9131785495297183, 8, 'log_loss', 100, 4),
#  (0.9131785495297183, 8, 'entropy', 150, 3),
#  (0.9131785487514386, 8, 'log_loss', 50, 2),
#  (0.9131660737016354, 8, 'entropy', 300, 4),
#  (0.9131660690319554, 8, 'gini', 400, 4),
#  (0.9131660690319554, 8, 'gini', 200, 4),
#  (0.9131535986518322, 8, 'entropy', 50, 3),
#  (0.9131535978735524, 8, 'log_loss', 450, 4),
#  (0.9131535970952724, 8, 'log_loss', 100, 2),
#  (0.9131535963169922, 8, 'entropy', 50, 2),
#  (0.9131535947604323, 8, 'gini', 300, 3),
#  (0.9131535932038725, 8, 'gini', 250, 4),
#  (0.9131535932038725, 8, 'gini', 150, 3),
#  (0.9131535932038725, 8, 'gini', 50, 3),
#  (0.9131535924255925, 8, 'gini', 450, 3),
#  (0.913141122045469, 8, 'log_loss', 350, 4),
#  (0.913141122045469, 8, 'entropy', 100, 4),
#  (0.9131411181540694, 8, 'gini', 400, 3),
#  (0.9131411173757893, 8, 'gini', 150, 4),
#  (0.9131411173757893, 8, 'gini', 100, 3),
#  (0.9131411173757893, 8, 'gini', 50, 2),
#  (0.9131411150409494, 8, 'gini', 400, 2),
#  (0.9131286454391061, 8, 'entropy', 350, 3),
#  (0.9131286407694261, 8, 'gini', 200, 3),
#  (0.9131286407694261, 8, 'gini', 200, 2),
#  (0.9131286399911464, 8, 'gini', 300, 2),
#  (0.9131161657196232, 8, 'gini', 450, 4),
#  (0.9131161657196232, 8, 'gini', 350, 4),
#  (0.9131161657196232, 8, 'gini', 350, 3),
#  (0.9131161649413432, 8, 'gini', 300, 4),
#  (0.9131161649413432, 8, 'gini', 250, 3),
#  (0.9131161649413432, 8, 'gini', 150, 2),
#  (0.9131161633847832, 8, 'gini', 250, 2),
#  (0.9131036898915401, 8, 'gini', 50, 4),
#  (0.91310368911326, 8, 'gini', 100, 4),
#  (0.91310368833498, 8, 'gini', 100, 2),
#  (0.913078735122254, 8, 'gini', 450, 2),
#  (0.9129914066605123, 9, 'entropy', 150, 4),
#  (0.9129789292758692, 9, 'entropy', 250, 2),
#  (0.912953979176263, 9, 'entropy', 150, 3),
#  (0.912953978397983, 9, 'entropy', 100, 3),
#  (0.912953977619703, 9, 'entropy', 200, 3),
#  (0.9129415033481798, 9, 'log_loss', 250, 3),
#  (0.9129415025699, 9, 'entropy', 350, 4),
#  (0.9129415025698998, 9, 'log_loss', 450, 4),
#  (0.9129415025698998, 9, 'log_loss', 450, 3),
#  (0.9129415025698998, 9, 'log_loss', 150, 3),
#  (0.91294150179162, 9, 'log_loss', 200, 3),
#  (0.9129290282983769, 9, 'entropy', 400, 2),
#  (0.9129290267418169, 9, 'log_loss', 300, 2),
#  (0.9129290267418169, 9, 'entropy', 200, 2),
#  (0.9129290259635369, 9, 'entropy', 450, 4),
#  (0.9129165516920137, 9, 'entropy', 50, 2),
#  (0.9129165509137337, 9, 'log_loss', 350, 3),
#  (0.9129165509137337, 9, 'log_loss', 200, 4),
#  (0.9129165509137337, 9, 'log_loss', 200, 2),
#  (0.9129165509137337, 9, 'entropy', 150, 2),
#  (0.9129165501354539, 9, 'entropy', 400, 3),
#  (0.9129165493571737, 9, 'log_loss', 50, 2),
#  (0.9129040750856505, 9, 'log_loss', 100, 3),
#  (0.9129040743073707, 9, 'log_loss', 400, 4),
#  (0.9129040743073707, 9, 'log_loss', 150, 4),
#  (0.9129040743073707, 9, 'entropy', 50, 3),
#  (0.9129040735290908, 9, 'entropy', 450, 3),
#  (0.9128916000358476, 9, 'log_loss', 50, 3),
#  (0.9128916000358476, 9, 'entropy', 250, 3),
#  (0.9128915984792876, 9, 'log_loss', 350, 2),
#  (0.9128915984792876, 9, 'entropy', 450, 2),
#  (0.9128915984792876, 9, 'entropy', 50, 4),
#  (0.9128915977010076, 9, 'log_loss', 250, 2),
#  (0.9128915977010076, 9, 'entropy', 300, 2),
#  (0.9128791234294844, 9, 'log_loss', 450, 2),
#  (0.9128791234294844, 9, 'log_loss', 300, 3),
#  (0.9128791234294844, 9, 'log_loss', 50, 4),
#  (0.9128791234294844, 9, 'entropy', 250, 4),
#  (0.9128791226512046, 9, 'log_loss', 400, 3),
#  (0.9128791226512046, 9, 'log_loss', 250, 4),
#  (0.9128791226512044, 9, 'entropy', 350, 2),
#  (0.9128791226512044, 9, 'entropy', 200, 4),
#  (0.9128791195380845, 9, 'gini', 450, 3),
#  (0.9128666476014013, 9, 'log_loss', 100, 4),
#  (0.9128666476014013, 9, 'entropy', 350, 3),
#  (0.9128666476014013, 9, 'entropy', 100, 4),
#  (0.9128666468231215, 9, 'log_loss', 400, 2),
#  (0.9128666460448415, 9, 'entropy', 100, 2),
#  (0.9128541717733183, 9, 'log_loss', 100, 2),
#  (0.9128541717733183, 9, 'entropy', 400, 4),
#  (0.9128541709950383, 9, 'entropy', 300, 4),
#  (0.9128541702167583, 9, 'entropy', 300, 3),
#  (0.9128541655470785, 9, 'gini', 300, 4),
#  (0.9128541655470785, 9, 'gini', 50, 4),
#  (0.9128416951669551, 9, 'log_loss', 150, 2),
#  (0.9128416904972754, 9, 'gini', 350, 3),
#  (0.9128292193388722, 9, 'log_loss', 350, 4),
#  (0.9128292162257523, 9, 'gini', 250, 4),
#  (0.9128292154474723, 9, 'gini', 250, 3),
#  (0.9128167388411091, 9, 'gini', 400, 3),
#  (0.9128042669044261, 9, 'log_loss', 300, 4),
#  (0.9128042614564661, 9, 'gini', 100, 3),
#  (0.912791787963223, 9, 'gini', 350, 4),
#  (0.912791787963223, 9, 'gini', 100, 4),
#  (0.9127917848501031, 9, 'gini', 250, 2),
#  (0.9127917840718232, 9, 'gini', 150, 2),
#  (0.9127793121351399, 9, 'gini', 400, 4),
#  (0.9127793113568599, 9, 'gini', 150, 3),
#  (0.9127793113568599, 9, 'gini', 50, 3),
#  (0.91277931057858, 9, 'gini', 150, 4),
#  (0.91277930824374, 9, 'gini', 450, 2),
#  (0.9127668355287769, 9, 'gini', 200, 4),
#  (0.9127668339722168, 9, 'gini', 450, 4),
#  (0.9127668339722168, 9, 'gini', 300, 3),
#  (0.9127668339722168, 9, 'gini', 200, 3),
#  (0.9127543558092939, 9, 'gini', 350, 2),
#  (0.9127418799812108, 9, 'gini', 400, 2),
#  (0.9127418799812108, 9, 'gini', 50, 2),
#  (0.9127294041531278, 9, 'gini', 200, 2),
#  (0.9127169291033246, 9, 'gini', 300, 2),
#  (0.9126919766688785, 9, 'gini', 100, 2)]

# %%
history = []
for depth in range(5, 10):
    print(depth)
    for criterion in ("gini", "entropy", "log_loss"):
        for n_estimators in range(50, 500, 50):
            for split in range(2, 5):
                reg = DecisionTreeClassifier(max_depth = depth, criterion = criterion, min_samples_split = split)
                cvs = cross_val_score(reg, X_res, y_res, cv=5, scoring="accuracy")
                mean_cvs = np.mean(cvs)
                history.append((np.abs(mean_cvs), depth, criterion, n_estimators,split))

# %%
sorted(history)[::-1]
